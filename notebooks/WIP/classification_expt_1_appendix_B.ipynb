# %% [markdown]
# ## Appendix B: Feature engineering. Get ready for classification modeling

# %%
import h5py 
import numpy as np 
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
import sys
import glob
import warnings

# %% [markdown]
# #### 1.0: Read hit data

# %%
df_hit_data = pd.read_csv("data_0/df_hit_data.csv")

# %%
# only keep in-time hits
df_hit_data = df_hit_data.query('abs(chod_delta) <= 0.5')

# %%
# drop irrelevant cols to reduce size of dt
df_hit_data = df_hit_data.drop(['x', 
                                'y',
                                'mirror',
                                'hit_time',
                                'chod_time',
                                'chod_delta'
                                ], axis=1)
df_hit_data
# Out:
#           Unnamed: 0  x_realigned  y_realigned  label   event   momentum  \
# 0                  0       -101.8  -269.219998      1       0  20.778881
# 1                  1       -173.8  -113.329999      1       0  20.778881
# 2                  2       -191.8    42.549998      1       0  20.778881
# 3                  3        -92.8   120.500003      1       0  20.778881
# 5                  5         87.2   -35.390000      1       0  20.778881
# ...              ...          ...          ...    ...     ...        ...
# 38058006    38058006          1.3   -25.090000      0  900699  44.893456
# 38058007    38058007       -349.7  -103.029999      0  900699  44.893456
# 38058008    38058008       -124.7  -180.970001      0  900699  44.893456
# 38058009    38058009       -322.7    37.270000      0  900699  44.893456
# 38058010    38058010        -70.7  -149.800003      0  900699  44.893456
#
#           track_pos_x  track_pos_y  ring_radius_cal  event_id
# 0           -58.20177   -22.614530       152.531027   2155500
# 1           -58.20177   -22.614530       152.531027   2155500
# 2           -58.20177   -22.614530       152.531027   2155500
# 3           -58.20177   -22.614530       152.531027   2155500
# 5           -58.20177   -22.614530       152.531027   2155500
# ...               ...          ...              ...       ...
# 38058006   -171.59705    -0.669099       186.290323    778557
# 38058007   -171.59705    -0.669099       186.290323    778557
# 38058008   -171.59705    -0.669099       186.290323    778557
# 38058009   -171.59705    -0.669099       186.290323    778557
# 38058010   -171.59705    -0.669099       186.290323    778557
#
# [15534413 rows x 10 columns]

# %%
df_hit_data = df_hit_data.reset_index()

# %% [markdown]
# #### 2.0: Process and get engineered features

# %%
# comupter distance
df_hit_data['distance'] = (
    (df_hit_data["track_pos_x"] - df_hit_data["x_realigned"]) ** 2 +
    (df_hit_data["track_pos_y"] - df_hit_data["y_realigned"]) ** 2
) ** 0.5

# %%
# comupter x+y and x-y
df_hit_data['x+y'] = df_hit_data['x_realigned'] + df_hit_data['y_realigned']
df_hit_data['x-y'] = df_hit_data['x_realigned'] - df_hit_data['y_realigned']

# %%
# %%time
rms = lambda x: np.sqrt(np.mean(x**2))
grouped_hit_data = df_hit_data.groupby('event').agg(
    {'x_realigned':['min', 'max', 'median'], 
     'y_realigned':['min','max', 'median'],
     'x+y': ['idxmin', 'idxmax'],
     'x-y': ['idxmin', 'idxmax'],
     'distance': ['min', 'max', 'mean', 'median', rms],
     'momentum': ['mean'],
     'label': ['mean'],
     'ring_radius_cal': ['mean'],
     'track_pos_x': ['mean'],
     'track_pos_y': ['mean']
    })
grouped_hit_data.columns = ['x_realigned_min', 
                            'x_realigned_max',
                            'x_realigned_median',
                            'y_realigned_min', 
                            'y_realigned_max',
                            'y_realigned_median',
                            'index_min(x+y)', 
                            'index_max(x+y)', 
                            'index_min(x-y)', 
                            'index_max(x-y)', 
                            'min_hit_radius', 
                            'max_hit_radius', 
                            'mean_hit_radius', 
                            'median_hit_radius', 
                            'rms_hit_radius',
                            'momentum',
                            'label',
                            'ring_radius_cal',
                            'track_pos_x',
                            'track_pos_y'
                            ]
grouped_hit_data = grouped_hit_data.reset_index()
# Out:
# CPU times: user 2min 42s, sys: 6.87 s, total: 2min 48s
# Wall time: 2min 43s

# %%
grouped_hit_data['x_min_sum'] = grouped_hit_data['index_min(x+y)'].apply(lambda x: df_hit_data.iloc[x]['x_realigned'])
grouped_hit_data['y_min_sum'] = grouped_hit_data['index_min(x+y)'].apply(lambda x: df_hit_data.iloc[x]['y_realigned'])

grouped_hit_data['x_max_sum'] = grouped_hit_data['index_max(x+y)'].apply(lambda x: df_hit_data.iloc[x]['x_realigned'])
grouped_hit_data['y_max_sum'] = grouped_hit_data['index_max(x+y)'].apply(lambda x: df_hit_data.iloc[x]['y_realigned'])

grouped_hit_data['x_min_diff'] = grouped_hit_data['index_min(x-y)'].apply(lambda x: df_hit_data.iloc[x]['x_realigned'])
grouped_hit_data['y_min_diff'] = grouped_hit_data['index_min(x-y)'].apply(lambda x: df_hit_data.iloc[x]['y_realigned'])

grouped_hit_data['x_max_diff'] = grouped_hit_data['index_max(x-y)'].apply(lambda x: df_hit_data.iloc[x]['x_realigned'])
grouped_hit_data['y_max_diff'] = grouped_hit_data['index_max(x-y)'].apply(lambda x: df_hit_data.iloc[x]['y_realigned'])

# %%
grouped_hit_data = grouped_hit_data.drop(columns=['index_min(x+y)', 
                                                  'index_max(x+y)', 
                                                  'index_min(x-y)', 
                                                  'index_max(x-y)'])

# %%
grouped_hit_data['max_x-min_x'] = grouped_hit_data['x_realigned_max']-grouped_hit_data['x_realigned_min']
grouped_hit_data['max_y-min_y'] = grouped_hit_data['y_realigned_max']-grouped_hit_data['y_realigned_min']

# %%
grouped_hit_data
# Out:
#          event  x_realigned_min  x_realigned_max  x_realigned_median  \
# 0            0           -191.8             87.2              -101.8
# 1            1           -322.7            -34.7               -79.7
# 2            2           -209.8            132.2                15.2
# 3            3           -263.8             78.2              -133.3
# 4            4           -263.8             78.2              -182.8
# ...        ...              ...              ...                 ...
# 900646  900695           -250.7             55.3               -57.2
# 900647  900696           -250.7            -34.7              -196.7
# 900648  900697           -227.8             15.2              -115.3
# 900649  900698           -218.8             51.2              -155.8
# 900650  900699           -367.7             19.3              -205.7
#
#         y_realigned_min  y_realigned_max  y_realigned_median  min_hit_radius  \
# 0           -269.219998       120.500003          -35.390000      110.145177
# 1             -9.500000       130.800003           52.849998      146.309490
# 2           -113.329999       104.909999           -4.215001      163.124895
# 3           -269.219998        42.549998         -144.509999      124.472915
# 4            -50.980000       276.379993           89.319999      143.818986
# ...                 ...              ...                 ...             ...
# 900646      -118.620003       255.500000           21.680000      141.092828
# 900647      -118.620003       255.500000          -56.270000      182.033911
# 900648      -175.680005       214.030002           50.345000      182.146891
# 900649      -128.920003        73.729999          -50.980000      178.590139
# 900650      -180.970001       177.559998           37.270000      138.404373
#
#         max_hit_radius  mean_hit_radius  ...  x_min_sum   y_min_sum  \
# 0           259.133431       172.642014  ...     -137.8 -269.219998
# 1           175.447550       166.862196  ...     -322.7   37.270000
# 2           180.984803       172.711909  ...     -164.8  -66.570000
# 3           200.620658       167.970376  ...     -263.8 -175.680005
# 4           194.906198       169.622280  ...     -191.8  -50.980000
# ...                ...              ...  ...        ...         ...
# 900646      206.526419       186.128292  ...     -250.7  -87.440002
# 900647      217.539843       194.252565  ...     -250.7  -87.440002
# 900648      236.412036       199.895585  ...     -119.8 -175.680005
# 900649      211.824059       193.054460  ...     -191.8  -50.980000
# 900650      205.422527       180.840607  ...     -349.7 -103.029999
#
#         x_max_sum   y_max_sum  x_min_diff  y_min_diff  x_max_diff  y_max_diff  \
# 0            87.2  -35.390000      -191.8   42.549998      -101.8 -269.219998
# 1           -34.7  130.800003      -322.7   37.270000       -79.7   52.849998
# 2           132.2   73.729999      -209.8  104.909999        78.2  -50.980000
# 3            78.2  -82.149998      -227.8   11.380000        60.2 -175.680005
# 4            78.2  167.259998      -146.8  276.379993        78.2  104.909999
# ...           ...         ...         ...         ...         ...         ...
# 900646      -34.7  224.330002      -232.7  255.500000        -7.7  -71.849998
# 900647     -178.7  255.500000      -232.7  255.500000       -34.7  -87.440002
# 900648       15.2  214.030002      -227.8   11.380000      -101.8 -175.680005
# 900649       51.2 -128.920003      -218.8   58.140002        51.2 -128.920003
# 900650      -70.7  161.970001      -367.7   52.849998       -70.7 -149.800003
#
#         max_x-min_x  max_y-min_y
# 0             279.0   389.720001
# 1             288.0   140.300003
# 2             342.0   218.239998
# 3             342.0   311.769997
# 4             342.0   327.359993
# ...             ...          ...
# 900646        306.0   374.120003
# 900647        216.0   374.120003
# 900648        243.0   389.710007
# 900649        270.0   202.650002
# 900650        387.0   358.529999
#
# [900651 rows x 27 columns]

# %%
grouped_hit_data['num_hits'] = df_hit_data.groupby('event').size()
#grouped_hit_data['num_hits'] = grouped_hit_data['num_hits'].astype('int')

# %%
grouped_hit_data.query('num_hits.isnull()')
# Out:
#          event  x_realigned_min  x_realigned_max  x_realigned_median  \
# 13870    13871           -367.7            -79.7              -205.7
# 24824    24826           -200.8            141.2              -133.3
# 26782    26785           -254.8             78.2              -101.8
# 28721    28725           -218.8            114.2               -25.3
# 40377    40382           -200.8            141.2               -25.3
# 41987    41993           -173.8            132.2               -88.3
# 68126    68133           -358.7            141.2               -43.3
# 83862    83870           -358.7            -61.7              -241.7
# 86118    86127           -412.7            -70.7              -340.7
# 115159  115169           -137.8            141.2                96.2
# 135230  135241           -412.7            -43.7              -277.7
# 143372  143384           -254.8            114.2                33.2
# 146924  146937           -308.8             96.2               -47.8
# 181047  181061           -317.8             42.2               -43.3
# 198241  198256           -304.7             46.3                -3.2
# 217288  217304           -448.7            -97.7              -331.7
# 222350  222367           -313.7             69.2              -228.2
# 238569  238587           -448.7            -61.7              -165.2
# 259358  259377           -448.7            -79.7              -322.7
# 292474  292494           -277.7            123.2              -119.8
# 311535  311556           -394.7            -34.7              -322.7
# 327980  328002           -164.8             87.2               -11.8
# 330140  330163           -421.7            -79.7              -241.7
# 351033  351057           -313.7            -88.7              -147.2
# 817763  120.500003      -110.8  120.500003       105.2 -191.270001
# 827675  193.149994      -277.7  208.740005        19.3   68.440002
# 853732   73.729999      -250.7  130.800003       105.2   -4.210000
# 874946   21.680000      -169.7   84.029999       -97.7 -290.089996
#
#         max_x-min_x  max_y-min_y  num_hits
# 13870         288.0   264.999996       NaN
# 24824         342.0   311.769997       NaN
# 26782         333.0   342.940002       NaN
# 28721         333.0   358.540009       NaN
# 40377         342.0   342.950005       NaN
# 41987         306.0   327.359993       NaN
# 68126         499.9   374.119995       NaN
# 83862         297.0   280.599998       NaN
# 86118         342.0   187.060001       NaN
# 115159        279.0   342.940002       NaN
# 135230        369.0   280.600002       NaN
# 143372        369.0   265.010006       NaN
# 146924        405.0   342.939995       NaN
# 181047        360.0   342.949993       NaN
# 198241        351.0   233.829998       NaN
# 217288        351.0   358.529999       NaN
# 222350        382.9   311.769997       NaN
# 238569        387.0   218.240005       NaN
# 259358        369.0   280.600002       NaN
# 292474        400.9   358.529999       NaN
# 311535        360.0   311.769997       NaN
# 327980        252.0   374.119995       NaN
# 330140        342.0   436.480011       NaN
# 351033        225.0   202.650005       NaN
# 354390        342.0   358.540001       NaN
# 396425        342.0   327.349998       NaN
# 417865        324.0   389.709991       NaN
# 418522        328.9   405.300003       NaN
# 418992        252.0   358.529999       NaN
# 440821        378.0   280.589996       NaN
# 486200        364.9   342.940002       NaN
# 493934        342.0   233.820007       NaN
# 499556        297.0   389.709991       NaN
# 504186        342.0   327.360001       NaN
# 516336        297.0   342.939995       NaN
# 552187        387.0   358.529999       NaN
# 575640        342.0   405.300003       NaN
# 619245        405.0   332.650005       NaN
# 655788        396.0   342.949997       NaN
# 681450        279.0   405.300003       NaN
# 691353        400.9   374.119995       NaN
# 719747        378.0   374.119995       NaN
# 740618        387.0   374.130005       NaN
# 789009        342.0   374.119995       NaN
# 802408        342.0   374.129997       NaN
# 817763        342.0   342.949997       NaN
# 827675        396.0   202.650005       NaN
# 853732        391.9   265.010002       NaN
# 874946        243.0   389.709999       NaN
#
# [49 rows x 28 columns]

# %%
grouped_hit_data = grouped_hit_data.dropna(axis=0) # drop rows which contain missing values
grouped_hit_data['num_hits'] = grouped_hit_data['num_hits'].astype('int')
# Out:
# /var/folders/1f/28l6t8yx0szdzx04c1sk6kfc0000gn/T/ipykernel_3078/1087643340.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_hit_data['num_hits'] = grouped_hit_data['num_hits'].astype('int')

# %%
grouped_hit_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 900602 entries, 0 to 900650
# Data columns (total 28 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   event               900602 non-null  int64
#  1   x_realigned_min     900602 non-null  float64
#  2   x_realigned_max     900602 non-null  float64
#  3   x_realigned_median  900602 non-null  float64
#  4   y_realigned_min     900602 non-null  float64
#  5   y_realigned_max     900602 non-null  float64
#  6   y_realigned_median  900602 non-null  float64
#  7   min_hit_radius      900602 non-null  float64
#  8   max_hit_radius      900602 non-null  float64
#  9   mean_hit_radius     900602 non-null  float64
#  10  median_hit_radius   900602 non-null  float64
#  11  rms_hit_radius      900602 non-null  float64
#  12  momentum            900602 non-null  float64
#  13  label               900602 non-null  float64
#  14  ring_radius_cal     900602 non-null  float64
#  15  track_pos_x         900602 non-null  float64
#  16  track_pos_y         900602 non-null  float64
#  17  x_min_sum           900602 non-null  float64
#  18  y_min_sum           900602 non-null  float64
#  19  x_max_sum           900602 non-null  float64
#  20  y_max_sum           900602 non-null  float64
#  21  x_min_diff          900602 non-null  float64
#  22  y_min_diff          900602 non-null  float64
#  23  x_max_diff          900602 non-null  float64
#  24  y_max_diff          900602 non-null  float64
#  25  max_x-min_x         900602 non-null  float64
#  26  max_y-min_y         900602 non-null  float64
#  27  num_hits            900602 non-null  int64
# dtypes: float64(26), int64(2)
# memory usage: 199.3 MB

# %%
grouped_hit_data.describe()
# Out:
#                event  x_realigned_min  x_realigned_max  x_realigned_median  \
# count  900602.000000    900602.000000    900602.000000       900602.000000
# mean   450356.234069      -296.975266        43.507897         -142.537454
# std    260008.891980        84.272724        70.376959           85.921143
# min         0.000000      -493.700000      -457.700000         -475.700000
# 25%    225184.250000      -367.700000        -7.700000         -196.700000
# 50%    450360.500000      -290.800000        51.200000         -138.200000
# 75%    675528.750000      -227.800000       105.200000          -83.800000
# max    900699.000000       150.200000       150.200000          150.200000
#
#        y_realigned_min  y_realigned_max  y_realigned_median  min_hit_radius  \
# count    900602.000000    900602.000000       900602.000000   900602.000000
# mean       -185.275735       156.487075          -20.042686      149.391772
# std          83.788914        76.762505           87.434871       21.903477
# min        -315.979993      -300.389996         -300.389996        0.468424
# 25%        -258.919998        89.320003          -82.149998      141.306831
# 50%        -191.270001       167.259998          -17.295000      151.321513
# 75%        -118.620003       224.330002           42.549998      162.224746
# max         255.500000       286.679993          263.294998      407.138399
#
#        max_hit_radius  mean_hit_radius  ...      y_min_sum      x_max_sum  \
# count   900602.000000    900602.000000  ...  900602.000000  900602.000000
# mean       219.922764       182.869971  ...    -130.137827      -2.219669
# std         30.380170         9.294614  ...      96.158227      91.605983
# min         57.126125        35.117506  ...    -315.979993    -475.700000
# 25%        206.458261       178.029189  ...    -206.859998     -61.700000
# 50%        215.794863       183.635207  ...    -128.920003       6.200000
# 75%        224.433838       187.976924  ...     -50.980000      69.200000
# max        510.473803       453.741037  ...     255.500000     150.200000
#
#            y_max_sum     x_min_diff     y_min_diff     x_max_diff  \
# count  900602.000000  900602.000000  900602.000000  900602.000000
# mean      103.889386    -247.159938     108.688064      -6.525422
# std        88.719766      94.292675      92.405989      82.874152
# min      -315.979993    -493.700000    -315.979993    -475.700000
# 25%        42.549998    -322.700000      42.549998     -61.700000
# 50%       104.909999    -236.800000     115.209999       1.300000
# 75%       177.559998    -173.800000     182.849994      60.200000
# max       286.679993     150.200000     286.679993     150.200000
#
#           y_max_diff    max_x-min_x    max_y-min_y       num_hits
# count  900602.000000  900602.000000  900602.000000  900602.000000
# mean     -138.094416     340.483163     341.762810      17.247942
# std        95.979273      60.470456      58.764819       5.983424
# min      -315.979993       0.000000       0.000000       1.000000
# 25%      -212.149994     315.000000     322.069997      13.000000
# 50%      -144.509999     355.900000     358.529999      17.000000
# 75%       -66.570000     378.000000     374.129997      21.000000
# max       271.089996     643.900000     602.659985      89.000000
#
# [8 rows x 28 columns]

# %%
# grouped_hit_data.to_csv('data_0/grouped_hit_data.csv')
