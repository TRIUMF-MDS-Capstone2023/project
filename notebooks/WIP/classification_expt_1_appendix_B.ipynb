# %% [markdown]
# ## Appendix B: Feature engineering. Get ready for classification modeling

# %% [markdown]
# **UPDATE**: Use **relative** hit positions ONLY for feature engineering and modeling.

# %%
import h5py 
import numpy as np 
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
import sys
import glob
import warnings

# %% [markdown]
# #### 1.0: Read hit data

# %%
# read hit data from local
df_hit_data = pd.read_csv("../../../data_0/df_hit_data.csv")

# %%
# only keep in-time hits
df_hit_data = df_hit_data.query('abs(chod_delta) <= 0.5')

# %%
# drop irrelevant cols to reduce size of dt
df_hit_data = df_hit_data.drop(['x', 
                                'y',
                                'mirror',
                                'hit_time',
                                'chod_time',
                                'chod_delta'
                                ], axis=1)
df_hit_data
# Out:
#           Unnamed: 0  x_realigned  y_realigned  label   event   momentum  \
# 0                  0       -101.8  -269.219998      1       0  20.778881
# 1                  1       -173.8  -113.329999      1       0  20.778881
# 2                  2       -191.8    42.549998      1       0  20.778881
# 3                  3        -92.8   120.500003      1       0  20.778881
# 5                  5         87.2   -35.390000      1       0  20.778881
# ...              ...          ...          ...    ...     ...        ...
# 38058006    38058006          1.3   -25.090000      0  900699  44.893456
# 38058007    38058007       -349.7  -103.029999      0  900699  44.893456
# 38058008    38058008       -124.7  -180.970001      0  900699  44.893456
# 38058009    38058009       -322.7    37.270000      0  900699  44.893456
# 38058010    38058010        -70.7  -149.800003      0  900699  44.893456
#
#           track_pos_x  track_pos_y  ring_radius_cal  event_id
# 0           -58.20177   -22.614530       152.531027   2155500
# 1           -58.20177   -22.614530       152.531027   2155500
# 2           -58.20177   -22.614530       152.531027   2155500
# 3           -58.20177   -22.614530       152.531027   2155500
# 5           -58.20177   -22.614530       152.531027   2155500
# ...               ...          ...              ...       ...
# 38058006   -171.59705    -0.669099       186.290323    778557
# 38058007   -171.59705    -0.669099       186.290323    778557
# 38058008   -171.59705    -0.669099       186.290323    778557
# 38058009   -171.59705    -0.669099       186.290323    778557
# 38058010   -171.59705    -0.669099       186.290323    778557
#
# [15534413 rows x 10 columns]

# %%
df_hit_data = df_hit_data.reset_index()

# %%
## update hit position as relative to track_pos

df_hit_data['x_realigned'] = df_hit_data['x_realigned'] - df_hit_data['track_pos_x']
df_hit_data['y_realigned'] = df_hit_data['y_realigned'] - df_hit_data['track_pos_y']

# %% [markdown]
# #### 2.0: Process and get engineered features

# %%
# comupter distance
df_hit_data['distance'] = (
    (df_hit_data["track_pos_x"] - df_hit_data["x_realigned"]) ** 2 +
    (df_hit_data["track_pos_y"] - df_hit_data["y_realigned"]) ** 2
) ** 0.5

# %%
# comupter x+y and x-y
df_hit_data['x+y'] = df_hit_data['x_realigned'] + df_hit_data['y_realigned']
df_hit_data['x-y'] = df_hit_data['x_realigned'] - df_hit_data['y_realigned']

# %%
# %%time
rms = lambda x: np.sqrt(np.mean(x**2))
grouped_hit_data = df_hit_data.groupby('event').agg(
    {'x_realigned':['min', 'max', 'median'], 
     'y_realigned':['min','max', 'median'],
     'x+y': ['idxmin', 'idxmax'],
     'x-y': ['idxmin', 'idxmax'],
     'distance': ['min', 'max', 'mean', 'median', rms],
     'momentum': ['mean'],
     'label': ['mean'],
     # 'ring_radius_cal': ['mean'],
     # 'track_pos_x': ['mean'],
     # 'track_pos_y': ['mean']
    })
grouped_hit_data.columns = ['x_realigned_min', 
                            'x_realigned_max',
                            'x_realigned_median',
                            'y_realigned_min', 
                            'y_realigned_max',
                            'y_realigned_median',
                            'index_min(x+y)', 
                            'index_max(x+y)', 
                            'index_min(x-y)', 
                            'index_max(x-y)', 
                            'min_hit_radius', 
                            'max_hit_radius', 
                            'mean_hit_radius', 
                            'median_hit_radius', 
                            'rms_hit_radius',
                            'momentum',
                            'label',
                            # 'ring_radius_cal',
                            # 'track_pos_x',
                            # 'track_pos_y'
                            ]
grouped_hit_data = grouped_hit_data.reset_index()
# Out:
# CPU times: user 2min 42s, sys: 6.25 s, total: 2min 48s
# Wall time: 2min 43s

# %%
grouped_hit_data['x_min_sum'] = grouped_hit_data['index_min(x+y)'].apply(lambda x: df_hit_data.iloc[x]['x_realigned'])
grouped_hit_data['y_min_sum'] = grouped_hit_data['index_min(x+y)'].apply(lambda x: df_hit_data.iloc[x]['y_realigned'])

grouped_hit_data['x_max_sum'] = grouped_hit_data['index_max(x+y)'].apply(lambda x: df_hit_data.iloc[x]['x_realigned'])
grouped_hit_data['y_max_sum'] = grouped_hit_data['index_max(x+y)'].apply(lambda x: df_hit_data.iloc[x]['y_realigned'])

grouped_hit_data['x_min_diff'] = grouped_hit_data['index_min(x-y)'].apply(lambda x: df_hit_data.iloc[x]['x_realigned'])
grouped_hit_data['y_min_diff'] = grouped_hit_data['index_min(x-y)'].apply(lambda x: df_hit_data.iloc[x]['y_realigned'])

grouped_hit_data['x_max_diff'] = grouped_hit_data['index_max(x-y)'].apply(lambda x: df_hit_data.iloc[x]['x_realigned'])
grouped_hit_data['y_max_diff'] = grouped_hit_data['index_max(x-y)'].apply(lambda x: df_hit_data.iloc[x]['y_realigned'])

# %%
grouped_hit_data = grouped_hit_data.drop(columns=['index_min(x+y)', 
                                                  'index_max(x+y)', 
                                                  'index_min(x-y)', 
                                                  'index_max(x-y)'])

# %%
grouped_hit_data['max_x-min_x'] = grouped_hit_data['x_realigned_max']-grouped_hit_data['x_realigned_min']
grouped_hit_data['max_y-min_y'] = grouped_hit_data['y_realigned_max']-grouped_hit_data['y_realigned_min']

# %%
grouped_hit_data
# Out:
#          event  x_realigned_min  x_realigned_max  x_realigned_median  \
# 0            0      -133.598230       145.401770          -43.598230
# 1            1      -120.844790       167.155210          122.155210
# 2            2      -162.284234       179.715766           62.715766
# 3            3      -181.836470       160.163530          -51.336470
# 4            4      -171.362450       170.637550          -90.362450
# ...        ...              ...              ...                 ...
# 900646  900695      -119.722800       186.277200           73.777200
# 900647  900696      -135.834860        80.165140          -81.834860
# 900648  900697      -230.394048        12.605952         -117.894048
# 900649  900698      -211.585942        58.414058         -148.585942
# 900650  900699      -196.102950       190.897050          -34.102950
#
#         y_realigned_min  y_realigned_max  y_realigned_median  min_hit_radius  \
# 0           -246.605468       143.114533          -12.775470       89.062290
# 1           -173.964260       -33.664257         -111.614262      302.700149
# 2           -177.274909        40.965089          -68.159911      117.046458
# 3           -178.299338       133.470658          -53.589339       64.169418
# 4           -167.676860       159.683133          -27.376861       57.424149
# ...                 ...              ...                 ...             ...
# 900646      -194.382323       179.737680          -54.082320      108.012478
# 900647      -201.099023       173.020980         -138.749020       59.446186
# 900648      -153.634297       236.075710           72.390708      169.593660
# 900649      -177.019040        25.630962          -99.079037      178.789260
# 900650      -180.300902       178.229097           37.939100       43.710424
#
#         max_hit_radius  mean_hit_radius  ...   x_min_sum   y_min_sum  \
# 0           225.010553       170.484039  ...  -79.598230 -246.605468
# 1           425.678402       386.590638  ... -120.844790 -127.194260
# 2           255.175408       217.406335  ... -117.284234 -130.514910
# 3           261.847041       159.538870  ... -181.836470  -84.759345
# 4           292.773931       222.763034  ...  -99.362450 -167.676860
# ...                ...              ...  ...         ...         ...
# 900646      349.000844       262.665393  ... -119.722800 -163.202322
# 900647      318.969563       191.483891  ... -135.834860 -169.919022
# 900648      258.315514       209.110429  ... -122.394048 -153.634297
# 900649      244.878926       217.994928  ... -184.585942  -99.079037
# 900650      363.271415       200.072925  ... -178.102950 -102.360899
#
#          x_max_sum   y_max_sum  x_min_diff  y_min_diff  x_max_diff  \
# 0       145.401770  -12.775470 -133.598230   65.164528  -43.598230
# 1       167.155210  -33.664257 -120.844790 -127.194260  122.155210
# 2       179.715766    9.785089 -162.284234   40.965089  125.715766
# 3       160.163530    8.770662 -145.836470  102.300660  142.163530
# 4       170.637550   50.563138  -54.362450  159.683133  170.637550
# ...            ...         ...         ...         ...         ...
# 900646   96.277200  148.567682 -101.722800  179.737680  123.277200
# 900647  -63.834860  173.020980 -117.834860  173.020980   80.165140
# 900648   12.605952  236.075710 -230.394048   33.425708 -104.394048
# 900649   58.414058 -177.019040 -211.585942   10.040965   58.414058
# 900650  100.897050  162.639101 -196.102950   53.519098  100.897050
#
#         y_max_diff  max_x-min_x  max_y-min_y
# 0      -246.605468        279.0   389.720001
# 1      -111.614262        288.0   140.300003
# 2      -114.924910        342.0   218.239998
# 3       -84.759345        342.0   311.769997
# 4       -11.786861        342.0   327.359993
# ...            ...          ...          ...
# 900646 -147.612318        306.0   374.120003
# 900647 -169.919022        216.0   374.120003
# 900648 -153.634297        243.0   389.710007
# 900649 -177.019040        270.0   202.650002
# 900650 -149.130904        387.0   358.529999
#
# [900651 rows x 24 columns]

# %%
grouped_hit_data['num_hits'] = df_hit_data.groupby('event').size()
#grouped_hit_data['num_hits'] = grouped_hit_data['num_hits'].astype('int')

# %%
grouped_hit_data.query('num_hits.isnull()')
# Out:
#          event  x_realigned_min  x_realigned_max  x_realigned_median  \
# 13870    13871      -148.471120       139.528880           13.528880
# 24824    24826      -176.570100       165.429900         -109.070100
# 26782    26785      -169.875680       163.124320          -16.875680
# 28721    28725      -170.717114       162.282886           22.782886
# 40377    40382      -169.621890       172.378110            5.878110
# 41987    41993      -135.095700       170.904300          -49.595700
# 68126    68133      -328.485360       171.414640          -13.085360
# 83862    83870      -177.451750       119.548250          -60.451750
# 86118    86127      -187.016650       154.983350         -115.016650
# 115159  115169      -117.587685       161.412315          116.412315
# 135230  135241      -195.354160       173.645840          -60.354160
# 143372  143384      -201.482400       167.517600           86.517600
# 146924  146937      -219.087920       185.912080           41.912080
# 181047  181061      -175.083230       184.916770           99.416770
# 198241  198256      -174.269000       176.731000          127.231000
# 217288  217304      -194.616440       156.383560          -77.616440
# 222350  222367      -197.598470       185.301530         -112.098470
# 238569  238587      -198.415850       188.584150           85.084150
# 691353  181.186549  -73.257270  165.596552   25.742730 -192.933446
# 719747  129.492970 -197.633010   82.722970   90.366990 -166.697028
# 740618  115.652562 -176.629430   84.472569  111.370570 -164.937435
# 789009  176.624771 -132.371140  161.034775  137.628860 -119.555225
# 802408  179.657111 -200.932284   54.947112   78.067716 -178.882890
# 817763  164.863273 -101.898502  164.863273  114.101498 -146.906731
# 827675  148.709434 -108.701940  164.299445  188.298060   23.999442
# 853732   -5.212451 -178.975830   51.857553  176.924170  -83.152450
# 874946  109.354600  -84.854730  171.704599  -12.854730 -202.415396
#
#         max_x-min_x  max_y-min_y  num_hits
# 13870         288.0   264.999996       NaN
# 24824         342.0   311.769997       NaN
# 26782         333.0   342.940002       NaN
# 28721         333.0   358.540009       NaN
# 40377         342.0   342.950005       NaN
# 41987         306.0   327.359993       NaN
# 68126         499.9   374.119995       NaN
# 83862         297.0   280.599998       NaN
# 86118         342.0   187.060001       NaN
# 115159        279.0   342.940002       NaN
# 135230        369.0   280.600002       NaN
# 143372        369.0   265.010006       NaN
# 146924        405.0   342.939995       NaN
# 181047        360.0   342.949993       NaN
# 198241        351.0   233.829998       NaN
# 217288        351.0   358.529999       NaN
# 222350        382.9   311.769997       NaN
# 238569        387.0   218.240005       NaN
# 259358        369.0   280.600002       NaN
# 292474        400.9   358.529999       NaN
# 311535        360.0   311.769997       NaN
# 327980        252.0   374.119995       NaN
# 330140        342.0   436.480011       NaN
# 351033        225.0   202.650005       NaN
# 354390        342.0   358.540001       NaN
# 396425        342.0   327.349998       NaN
# 417865        324.0   389.709991       NaN
# 418522        328.9   405.300003       NaN
# 418992        252.0   358.529999       NaN
# 440821        378.0   280.589996       NaN
# 486200        364.9   342.940002       NaN
# 493934        342.0   233.820007       NaN
# 499556        297.0   389.709991       NaN
# 504186        342.0   327.360001       NaN
# 516336        297.0   342.939995       NaN
# 552187        387.0   358.529999       NaN
# 575640        342.0   405.300003       NaN
# 619245        405.0   332.650005       NaN
# 655788        396.0   342.949997       NaN
# 681450        279.0   405.300003       NaN
# 691353        400.9   374.119995       NaN
# 719747        378.0   374.119995       NaN
# 740618        387.0   374.130005       NaN
# 789009        342.0   374.119995       NaN
# 802408        342.0   374.129997       NaN
# 817763        342.0   342.949997       NaN
# 827675        396.0   202.650005       NaN
# 853732        391.9   265.010002       NaN
# 874946        243.0   389.709999       NaN
#
# [49 rows x 25 columns]

# %%
grouped_hit_data = grouped_hit_data.dropna(axis=0) # drop rows which contain missing values
grouped_hit_data['num_hits'] = grouped_hit_data['num_hits'].astype('int')
# Out:
# /var/folders/1f/28l6t8yx0szdzx04c1sk6kfc0000gn/T/ipykernel_2337/1087643340.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grouped_hit_data['num_hits'] = grouped_hit_data['num_hits'].astype('int')

# %%
grouped_hit_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 900602 entries, 0 to 900650
# Data columns (total 25 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   event               900602 non-null  int64
#  1   x_realigned_min     900602 non-null  float64
#  2   x_realigned_max     900602 non-null  float64
#  3   x_realigned_median  900602 non-null  float64
#  4   y_realigned_min     900602 non-null  float64
#  5   y_realigned_max     900602 non-null  float64
#  6   y_realigned_median  900602 non-null  float64
#  7   min_hit_radius      900602 non-null  float64
#  8   max_hit_radius      900602 non-null  float64
#  9   mean_hit_radius     900602 non-null  float64
#  10  median_hit_radius   900602 non-null  float64
#  11  rms_hit_radius      900602 non-null  float64
#  12  momentum            900602 non-null  float64
#  13  label               900602 non-null  float64
#  14  x_min_sum           900602 non-null  float64
#  15  y_min_sum           900602 non-null  float64
#  16  x_max_sum           900602 non-null  float64
#  17  y_max_sum           900602 non-null  float64
#  18  x_min_diff          900602 non-null  float64
#  19  y_min_diff          900602 non-null  float64
#  20  x_max_diff          900602 non-null  float64
#  21  y_max_diff          900602 non-null  float64
#  22  max_x-min_x         900602 non-null  float64
#  23  max_y-min_y         900602 non-null  float64
#  24  num_hits            900602 non-null  int64
# dtypes: float64(23), int64(2)
# memory usage: 178.6 MB

# %%
grouped_hit_data.describe()
# Out:
#                event  x_realigned_min  x_realigned_max  x_realigned_median  \
# count  900602.000000    900602.000000    900602.000000       900602.000000
# mean   450356.234069      -191.883323       148.599840          -37.445512
# std    260008.891980        33.382534        52.780302           75.334058
# min         0.000000      -497.015619      -347.107518         -401.223224
# 25%    225184.250000      -208.269685       130.838168          -97.066191
# 50%    450360.500000      -195.204225       168.450085          -44.961300
# 75%    675528.750000      -179.935860       180.569235           16.601978
# max    900699.000000       404.465050       464.486900          404.465050
#
#        y_realigned_min  y_realigned_max  y_realigned_median  min_hit_radius  \
# count    900602.000000    900602.000000       900602.000000   900602.000000
# mean       -185.950940       155.811869          -20.717891       89.649465
# std          37.475724        47.790588           77.863747       54.630502
# min        -470.455953      -380.343275         -411.523268        0.040606
# 25%        -205.814963       147.973258          -81.538517       45.322431
# 50%        -190.789835       170.705384          -23.413407       84.360218
# 75%        -174.280331       180.536899           38.400134      128.276622
# max         342.483655       438.183453          358.073652      709.329379
#
#        max_hit_radius  mean_hit_radius  ...      y_min_sum      x_max_sum  \
# count   900602.000000    900602.000000  ...  900602.000000  900602.000000
# mean       326.918203       225.447298  ...    -130.813032     102.872274
# std         76.803907        49.192199  ...      57.760517      80.695346
# min         23.864236        15.699232  ...    -470.455953    -347.107518
# 25%        262.003299       188.577847  ...    -170.026768      73.909862
# 50%        330.073440       213.817159  ...    -137.454987     126.590880
# 75%        381.445268       253.659895  ...     -98.447174     159.840422
# max        789.257938       712.093105  ...     342.483655     461.237080
#
#            y_max_sum     x_min_diff     y_min_diff     x_max_diff  \
# count  900602.000000  900602.000000  900602.000000  900602.000000
# mean      103.214181    -142.067995     108.012859      98.566520
# std        78.953331      52.499955      59.218867      65.618091
# min      -411.523268    -497.015619    -380.343275    -374.582470
# 25%        72.129264    -174.652295      81.679593      68.223502
# 50%       126.027568    -147.778154     117.943083     110.646045
# 75%       158.999355    -114.448510     147.039173     143.960473
# max       438.183453     404.465050     438.183453     444.015280
#
#           y_max_diff    max_x-min_x    max_y-min_y       num_hits
# count  900602.000000  900602.000000  900602.000000  900602.000000
# mean     -138.769621     340.483163     341.762810      17.247942
# std        58.581893      60.470456      58.764819       5.983424
# min      -470.455953       0.000000       0.000000       1.000000
# 25%      -175.610183     315.000000     322.069997      13.000000
# 50%      -148.919529     355.900000     358.529999      17.000000
# 75%      -113.535311     378.000000     374.129997      21.000000
# max       342.483655     643.900000     602.659985      89.000000
#
# [8 rows x 25 columns]

# %%
# grouped_hit_data.to_csv('../../../data_0/grouped_hit_data_relative.csv')
