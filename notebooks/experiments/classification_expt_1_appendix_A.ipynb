# %% [markdown]
# ## Appendix A: Read raw data, uniform sample, and create df_hit_data

# %%
import h5py 
import numpy as np 
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
import sys
import glob
import warnings

# %%
# import functions from a local py file
from helpers import events_to_pandas
from helpers import calc_ring_radius
from helpers import get_string_label
from helpers import get_hit_info_df_rev_0
from helpers import compute_seq_id
from helpers import uniform_sampling

# %% [markdown]
# #### 1.0: Read raw data and remove irrelevant col/row

# %%
# load the h5py raw data provided by the TRIUMF team for MDS 2023 capstone project
f = h5py.File('data/CaloRICH_Run11100_CTRL_v1.h5', 'r')
f
# Out:
# <HDF5 file "CaloRICH_Run11100_CTRL_v1.h5" (mode r)>

# %%
datasets = list(f.keys())
datasets
# Out:
# ['Events', 'HitMapping', 'Hits']

# %%
# read the event dataset to pandas df
df = events_to_pandas(f)
df.head()
# Out:
#    run_id  burst_id  event_id  track_id  track_momentum  chod_time  \
# 0   11100      1468     11235         0       22.761024   7.789327
# 1   11100      1468     11812         0       23.600529   0.000198
# 2   11100      1468     14104         0       16.275131  11.789481
# 3   11100      1468     14634         1       36.436443   7.426493
# 4   11100      1468     18030         0       16.525362   8.923427
#
#    track_pos_x  track_pos_y  ring_radius  ring_centre_pos_x  \
# 0  -195.126602  -153.930786   172.410950        -190.112167
# 1  -316.197571   -57.275291   175.251694        -309.305939
# 2   -88.681786    58.657421   155.040802         -88.665840
# 3   -39.124882    81.853058   185.832642         -35.864372
# 4   -66.697784   -15.932317   158.641846         -65.450981
#
#    ring_centre_pos_y  ring_likelihood_pion  ring_likelihood_muon  \
# 0        -154.579514          2.083958e-12                   1.0
# 1         -54.844410          7.732010e-10                   1.0
# 2          59.053833          1.216099e-37                   1.0
# 3          80.708580          8.006046e-03                   1.0
# 4         -20.469883          1.216099e-37                   1.0
#
#    ring_likelihood_positron  label  first_hit  last_hit  total_hits
# 0              1.914225e-24      0          0        20          20
# 1              8.275686e-19      0         20        39          19
# 2              1.216099e-37      0         39        65          26
# 3              3.626212e-02      0         65       117          52
# 4              1.216099e-37      0        117       141          24

# %%
# drop irrelevant columns to reduce size of df
# drop id columns (keep event_id only for mapping to hit data
df = df.drop(['run_id', 'burst_id'], axis=1)
df.head()
# Out:
#    event_id  track_id  track_momentum  chod_time  track_pos_x  track_pos_y  \
# 0     11235         0       22.761024   7.789327  -195.126602  -153.930786
# 1     11812         0       23.600529   0.000198  -316.197571   -57.275291
# 2     14104         0       16.275131  11.789481   -88.681786    58.657421
# 3     14634         1       36.436443   7.426493   -39.124882    81.853058
# 4     18030         0       16.525362   8.923427   -66.697784   -15.932317
#
#    ring_radius  ring_centre_pos_x  ring_centre_pos_y  ring_likelihood_pion  \
# 0   172.410950        -190.112167        -154.579514          2.083958e-12
# 1   175.251694        -309.305939         -54.844410          7.732010e-10
# 2   155.040802         -88.665840          59.053833          1.216099e-37
# 3   185.832642         -35.864372          80.708580          8.006046e-03
# 4   158.641846         -65.450981         -20.469883          1.216099e-37
#
#    ring_likelihood_muon  ring_likelihood_positron  label  first_hit  last_hit  \
# 0                   1.0              1.914225e-24      0          0        20
# 1                   1.0              8.275686e-19      0         20        39
# 2                   1.0              1.216099e-37      0         39        65
# 3                   1.0              3.626212e-02      0         65       117
# 4                   1.0              1.216099e-37      0        117       141
#
#    total_hits
# 0          20
# 1          19
# 2          26
# 3          52
# 4          24

# %%
# count the number of three particles
df['label'].value_counts()
# Out:
# 0    2160219
# 1     215955
# 2      28515
# Name: label, dtype: int64

# %%
# drop positron with label #2 as this is not our interest at this time
df = df.drop(df[df.label == 2].index)
df['label'].value_counts()
# Out:
# 0    2160219
# 1     215955
# Name: label, dtype: int64

# %%
# drop irrelevant columns to reduce size of df
# drop columns which are output of current NA62 algorithm
df = df.drop(['ring_radius', 
              'ring_centre_pos_x', 
              'ring_centre_pos_y',
              'ring_likelihood_pion',
              'ring_likelihood_muon',
              'ring_likelihood_positron'
             ], axis=1)
df.head()
# Out:
#    event_id  track_id  track_momentum  chod_time  track_pos_x  track_pos_y  \
# 0     11235         0       22.761024   7.789327  -195.126602  -153.930786
# 1     11812         0       23.600529   0.000198  -316.197571   -57.275291
# 2     14104         0       16.275131  11.789481   -88.681786    58.657421
# 3     14634         1       36.436443   7.426493   -39.124882    81.853058
# 4     18030         0       16.525362   8.923427   -66.697784   -15.932317
#
#    label  first_hit  last_hit  total_hits
# 0      0          0        20          20
# 1      0         20        39          19
# 2      0         39        65          26
# 3      0         65       117          52
# 4      0        117       141          24

# %%
# drop rows with track_momentum out of [20,45]
df = df.drop(df[df.track_momentum <20].index)
df = df.drop(df[df.track_momentum >45].index)
df.describe()
# Out:
#            event_id      track_id  track_momentum     chod_time   track_pos_x  \
# count  1.552842e+06  1.552842e+06    1.552842e+06  1.552842e+06  1.552842e+06
# mean   1.348888e+06  1.143400e-01    3.306397e+01  1.236835e+01 -1.058141e+02
# std    7.364807e+05  3.464620e-01    6.647698e+00  8.560482e+00  8.151135e+01
# min    9.983000e+03  0.000000e+00    2.000000e+01 -2.438476e+01 -3.447701e+02
# 25%    7.310900e+05  0.000000e+00    2.776289e+01  5.854976e+00 -1.743368e+02
# 50%    1.339128e+06  0.000000e+00    3.318998e+01  1.243226e+01 -9.740569e+01
# 75%    1.920988e+06  0.000000e+00    3.851507e+01  1.901669e+01 -2.983885e+01
# max    2.823886e+06  9.000000e+00    4.499998e+01  4.930447e+01  1.613446e+01
#
#         track_pos_y         label     first_hit      last_hit    total_hits
# count  1.552842e+06  1.552842e+06  1.552842e+06  1.552842e+06  1.552842e+06
# mean   7.665038e-01  1.161445e-01  5.004159e+07  5.004163e+07  4.234876e+01
# std    8.355496e+01  3.203982e-01  2.928274e+07  2.928274e+07  2.327619e+01
# min   -1.717946e+02  0.000000e+00  0.000000e+00  2.000000e+01  5.000000e+00
# 25%   -7.660971e+01  0.000000e+00  2.430799e+07  2.430804e+07  2.500000e+01
# 50%    1.570445e+00  0.000000e+00  4.999102e+07  4.999105e+07  3.800000e+01
# 75%    7.853598e+01  0.000000e+00  7.574404e+07  7.574409e+07  5.500000e+01
# max    1.717478e+02  1.000000e+00  9.939703e+07  9.939708e+07  3.790000e+02

# %%
# add new column with the corresponding mass value for pion and muon
# refer to calc_ring_radius() function provided in TRIUMF repo for details
# mass of the particle in MeV/c^2
df['mass'] = [105.66 if x == 0 else 139.57 for x in df['label']]

# %%
# add new column with the calculated ring radius from the theoretical formula
# ring_radius_cal in mm (consistent with ring_radius in the event dataset)
# in below code, the first 1000 is to convert track_momentum from GeV/c to MeV/c
# the second 1000 is to convert ring_radius_cal from m to mm
df['ring_radius_cal'] = calc_ring_radius(df['mass'], df['track_momentum']*1000)*1000

# %%
df = df.reset_index(drop=True)
df.head()
# Out:
#    event_id  track_id  track_momentum  chod_time  track_pos_x  track_pos_y  \
# 0     11235         0       22.761024   7.789327  -195.126602  -153.930786
# 1     11812         0       23.600529   0.000198  -316.197571   -57.275291
# 2     14634         1       36.436443   7.426493   -39.124882    81.853058
# 3     18340         0       34.514111   0.684758  -206.711899    66.719482
# 4     25603         0       41.155918  20.199379  -152.587402    78.473106
#
#    label  first_hit  last_hit  total_hits    mass  ring_radius_cal
# 0      0          0        20          20  105.66       173.437630
# 1      0         20        39          19  105.66       174.649395
# 2      0         65       117          52  105.66       184.053395
# 3      0        141       190          49  105.66       183.284136
# 4      0        190       232          42  105.66       185.510338

# %%
# drop interim column 'mass'
df = df.drop(['mass'
             ], axis=1)
df.head()
# Out:
#    event_id  track_id  track_momentum  chod_time  track_pos_x  track_pos_y  \
# 0     11235         0       22.761024   7.789327  -195.126602  -153.930786
# 1     11812         0       23.600529   0.000198  -316.197571   -57.275291
# 2     14634         1       36.436443   7.426493   -39.124882    81.853058
# 3     18340         0       34.514111   0.684758  -206.711899    66.719482
# 4     25603         0       41.155918  20.199379  -152.587402    78.473106
#
#    label  first_hit  last_hit  total_hits  ring_radius_cal
# 0      0          0        20          20       173.437630
# 1      0         20        39          19       174.649395
# 2      0         65       117          52       184.053395
# 3      0        141       190          49       183.284136
# 4      0        190       232          42       185.510338

# %% [markdown]
# #### 2.0: Uniform sample data

# %%
df_sample = uniform_sampling(df)
df_sample
# Out:
#         event_id  track_id  track_momentum  chod_time  track_pos_x  \
# 0        2155500         0       20.778881  13.055243   -58.201771
# 1        2477694         0       20.048994  10.540932  -201.855209
# 2        1173336         0       20.881472  20.406666   -47.515766
# 3        2612686         0       20.109674   6.305044   -81.963531
# 4        2479300         0       20.928585   6.572837   -92.437553
# ...          ...       ...             ...        ...          ...
# 900695   1483227         0       44.295181  20.453075  -130.977203
# 900696    763612         0       44.697300   1.890692  -114.865143
# 900697   2484287         0       44.018299  24.262856     2.594048
# 900698   1475065         0       44.554790   4.770075    -7.214058
# 900699    778557         0       44.893456   8.657274  -171.597046
#
#         track_pos_y  label  first_hit  last_hit  total_hits  ring_radius_cal  \
# 0        -22.614531      1   96059752  96059769          17       152.531027
# 1        164.464264      0   57291267  57291283          16       168.160161
# 2         63.944908      0   85098090  85098108          18       170.029766
# 3        -90.920662      0   63719162  63719188          26       168.333388
# 4        116.696861      0   53813387  53813408          21       170.144083
# ...             ...    ...        ...       ...         ...              ...
# 900695    75.762321      0   34630754  34630844          90       186.192080
# 900696    82.479019      0   54776649  54776741          92       186.264814
# 900697   -22.045708      0   49145037  49145086          49       186.136482
# 900698    48.099037      0   12805241  12805270          29       186.261281
# 900699    -0.669099      0    1514242   1514261          19       186.290323
#
#        momentum_bin
# 0          (20, 21]
# 1          (20, 21]
# 2          (20, 21]
# 3          (20, 21]
# 4          (20, 21]
# ...             ...
# 900695     (44, 45]
# 900696     (44, 45]
# 900697     (44, 45]
# 900698     (44, 45]
# 900699     (44, 45]
#
# [900700 rows x 12 columns]

# %%
# df_sample.to_csv("data_0/df_sample.csv")

# %%
# %%time
hit_data = [get_hit_info_df_rev_0(f, df_sample, index) for index in df_sample.index]
# Out:
# CPU times: user 42min 29s, sys: 1min 21s, total: 43min 51s
# Wall time: 44min 47s

# %%
# %%time
df_hit_data = pd.concat(hit_data, axis=0, ignore_index=True)
# Out:
# CPU times: user 1min 49s, sys: 5min 28s, total: 7min 17s
# Wall time: 9min 57s

# %%
# %%time
# df_hit_data.to_csv("data_0/df_hit_data.csv")
# Out:
# CPU times: user 3min 8s, sys: 6.63 s, total: 3min 15s
# Wall time: 3min 23s

# %%
df_hit_data
# Out:
#               x           y  mirror  x_realigned  y_realigned   hit_time  \
# 0          45.0 -249.419998     0.0       -101.8  -269.219998  13.163244
# 1         -27.0  -93.529999     0.0       -173.8  -113.329999  13.077265
# 2         -45.0   62.349998     0.0       -191.8    42.549998  13.421317
# 3          54.0  140.300003     0.0        -92.8   120.500003  13.255676
# 4         243.0  -31.180000     0.0         96.2   -50.980000  12.519780
# ...         ...         ...     ...          ...          ...        ...
# 38058006  198.0  -15.590000     1.0          1.3   -25.090000   8.470926
# 38058007 -153.0  -93.529999     1.0       -349.7  -103.029999   8.188066
# 38058008   72.0 -171.470001     1.0       -124.7  -180.970001   8.767607
# 38058009 -126.0   46.770000     1.0       -322.7    37.270000   8.683517
# 38058010  126.0 -140.300003     1.0        -70.7  -149.800003   8.520926
#
#           chod_time  chod_delta  label   event   momentum  track_pos_x  \
# 0         13.055243    0.108001      1       0  20.778881   -58.201771
# 1         13.055243    0.022021      1       0  20.778881   -58.201771
# 2         13.055243    0.366074      1       0  20.778881   -58.201771
# 3         13.055243    0.200433      1       0  20.778881   -58.201771
# 4         13.055243   -0.535463      1       0  20.778881   -58.201771
# ...             ...         ...    ...     ...        ...          ...
# 38058006   8.657274   -0.186348      0  900699  44.893456  -171.597046
# 38058007   8.657274   -0.469208      0  900699  44.893456  -171.597046
# 38058008   8.657274    0.110332      0  900699  44.893456  -171.597046
# 38058009   8.657274    0.026242      0  900699  44.893456  -171.597046
# 38058010   8.657274   -0.136348      0  900699  44.893456  -171.597046
#
#           track_pos_y  ring_radius_cal  event_id
# 0          -22.614531       152.531027   2155500
# 1          -22.614531       152.531027   2155500
# 2          -22.614531       152.531027   2155500
# 3          -22.614531       152.531027   2155500
# 4          -22.614531       152.531027   2155500
# ...               ...              ...       ...
# 38058006    -0.669099       186.290323    778557
# 38058007    -0.669099       186.290323    778557
# 38058008    -0.669099       186.290323    778557
# 38058009    -0.669099       186.290323    778557
# 38058010    -0.669099       186.290323    778557
#
# [38058011 rows x 15 columns]

# %%
# only keep in-time hits
df_hit_data = df_hit_data.query('abs(chod_delta) <= 0.5')

# %%
# drop irrelevant cols to reduce size of dt
df_hit_data = df_hit_data.drop(['x', 
                                'y',
                                'mirror',
                                'hit_time',
                                'chod_time',
                                'chod_delta'
                                ], axis=1)
df_hit_data
# Out:
#           x_realigned  y_realigned  label   event   momentum  track_pos_x  \
# 0              -101.8  -269.219998      1       0  20.778881   -58.201771
# 1              -173.8  -113.329999      1       0  20.778881   -58.201771
# 2              -191.8    42.549998      1       0  20.778881   -58.201771
# 3               -92.8   120.500003      1       0  20.778881   -58.201771
# 5                87.2   -35.390000      1       0  20.778881   -58.201771
# ...               ...          ...    ...     ...        ...          ...
# 38058006          1.3   -25.090000      0  900699  44.893456  -171.597046
# 38058007       -349.7  -103.029999      0  900699  44.893456  -171.597046
# 38058008       -124.7  -180.970001      0  900699  44.893456  -171.597046
# 38058009       -322.7    37.270000      0  900699  44.893456  -171.597046
# 38058010        -70.7  -149.800003      0  900699  44.893456  -171.597046
#
#           track_pos_y  ring_radius_cal  event_id
# 0          -22.614531       152.531027   2155500
# 1          -22.614531       152.531027   2155500
# 2          -22.614531       152.531027   2155500
# 3          -22.614531       152.531027   2155500
# 5          -22.614531       152.531027   2155500
# ...               ...              ...       ...
# 38058006    -0.669099       186.290323    778557
# 38058007    -0.669099       186.290323    778557
# 38058008    -0.669099       186.290323    778557
# 38058009    -0.669099       186.290323    778557
# 38058010    -0.669099       186.290323    778557
#
# [15534413 rows x 9 columns]

# %%
df_hit_data = df_hit_data.reset_index()
