# %%
import pyarrow.parquet as pq
import pandas as pd
import numpy as np
import torch
device = 'cuda' if torch.cuda.is_available() else 'cpu'
import time
torch.backends.cudnn.benchmark = True
import os
import polars as pl
from torch.utils.data import Dataset
import platform
import seaborn as sbn
import matplotlib.pyplot as plt

# %%
residuals_df = pl.read_csv(r"C:\Users\merig\Documents\Projects\PointNet\results\PointNet_old\old_pointnet_second_test.csv")

# %%
residuals_df.head()
# Out:
# shape: (5, 5)
# ┌─────┬────────────┬─────────────┬───────────┬─────────────────────┐
# │     ┆ Predicted  ┆ Theoretical ┆ Residuals ┆ composite_events_id │
# │ --- ┆ ---        ┆ ---         ┆ ---       ┆ ---                 │
# │ i64 ┆ f64        ┆ f64         ┆ f64       ┆ i64                 │
# ╞═════╪════════════╪═════════════╪═══════════╪═════════════════════╡
# │ 0   ┆ 185.233139 ┆ 184.629135  ┆ -0.604004 ┆ 6102523641129904    │
# │ 1   ┆ 186.549438 ┆ 188.784668  ┆ 2.235229  ┆ 6102657571224176    │
# │ 2   ┆ 184.755554 ┆ 183.089539  ┆ -1.666016 ┆ 6102491148214624    │
# │ 3   ┆ 180.99826  ┆ 182.075027  ┆ 1.076767  ┆ 6102594748716032    │
# │ 4   ┆ 182.926208 ┆ 174.276138  ┆ -8.65007  ┆ 6102553157980704    │
# └─────┴────────────┴─────────────┴───────────┴─────────────────────┘

# %%
residuals_df['Residuals'].min()
# Out:
# -168.99717712402344

# %%
residuals_df = residuals_df.rename({'composite_events_id' : 'composite_event_id'})

# %%
residuals_df = residuals_df.with_columns(pl.col('composite_event_id').cast(pl.Int64))

# %%
residuals_df.head()
# Out:
# shape: (5, 5)
# ┌─────┬────────────┬─────────────┬───────────┬────────────────────┐
# │     ┆ Predicted  ┆ Theoretical ┆ Residuals ┆ composite_event_id │
# │ --- ┆ ---        ┆ ---         ┆ ---       ┆ ---                │
# │ i64 ┆ f64        ┆ f64         ┆ f64       ┆ i64                │
# ╞═════╪════════════╪═════════════╪═══════════╪════════════════════╡
# │ 0   ┆ 185.233139 ┆ 184.629135  ┆ -0.604004 ┆ 6102523641129904   │
# │ 1   ┆ 186.549438 ┆ 188.784668  ┆ 2.235229  ┆ 6102657571224176   │
# │ 2   ┆ 184.755554 ┆ 183.089539  ┆ -1.666016 ┆ 6102491148214624   │
# │ 3   ┆ 180.99826  ┆ 182.075027  ┆ 1.076767  ┆ 6102594748716032   │
# │ 4   ┆ 182.926208 ┆ 174.276138  ┆ -8.65007  ┆ 6102553157980704   │
# └─────┴────────────┴─────────────┴───────────┴────────────────────┘

# %%
sbn.scatterplot(residuals_df, x = 'Theoretical', y = 'Residuals', s = 1)
plt.axhline(y=0, color='red', linestyle='--')

# %% [markdown]
# Here we can see a distribution of the residuals that shows a trend in the residuals that is not following the zero line (red dotted line), meaning that the model is not learning the behaviour of the labels in the training data. This unfortunately means that the PointNet model is not working at the moment and point to the probability of a vanishing gradient.

# %%
events_df = pl.read_parquet(r"C:\Users\merig\Documents\Projects\PointNet\data\events.parquet")

# %%
type(events_df)
# Out:
# polars.dataframe.frame.DataFrame

# %%
events_df = events_df.with_columns(pl.col('composite_event_id').cast(pl.Int64))

# %%
events_df.head()
# Out:
# shape: (5, 24)
# ┌────────┬──────────┬──────────┬──────────┬───┬───────┬────────────┬───────────────┬───────────────┐
# │ run_id ┆ burst_id ┆ event_id ┆ track_id ┆ … ┆ class ┆ mass       ┆ composite_eve ┆ ring_radius_c │
# │ ---    ┆ ---      ┆ ---      ┆ ---      ┆   ┆ ---   ┆ ---        ┆ nt_id         ┆ al            │
# │ u32    ┆ u16      ┆ u64      ┆ u8       ┆   ┆ str   ┆ f32        ┆ ---           ┆ ---           │
# │        ┆          ┆          ┆          ┆   ┆       ┆            ┆ i64           ┆ f32           │
# ╞════════╪══════════╪══════════╪══════════╪═══╪═══════╪════════════╪═══════════════╪═══════════════╡
# │ 11100  ┆ 1468     ┆ 11235    ┆ 0        ┆ … ┆ muon  ┆ 105.660004 ┆ 6102683597585 ┆ 173.410156    │
# │        ┆          ┆          ┆          ┆   ┆       ┆            ┆ 968           ┆               │
# │ 11100  ┆ 1468     ┆ 11812    ┆ 0        ┆ … ┆ muon  ┆ 105.660004 ┆ 6102683597595 ┆ 174.660522    │
# │        ┆          ┆          ┆          ┆   ┆       ┆            ┆ 200           ┆               │
# │ 11100  ┆ 1468     ┆ 14104    ┆ 0        ┆ … ┆ muon  ┆ 105.660004 ┆ 6102683597631 ┆ 155.299332    │
# │        ┆          ┆          ┆          ┆   ┆       ┆            ┆ 872           ┆               │
# │ 11100  ┆ 1468     ┆ 14634    ┆ 1        ┆ … ┆ muon  ┆ 105.660004 ┆ 6102683597640 ┆ 184.0354      │
# │        ┆          ┆          ┆          ┆   ┆       ┆            ┆ 353           ┆               │
# │ 11100  ┆ 1468     ┆ 18030    ┆ 0        ┆ … ┆ muon  ┆ 105.660004 ┆ 6102683597694 ┆ 156.473602    │
# │        ┆          ┆          ┆          ┆   ┆       ┆            ┆ 688           ┆               │
# └────────┴──────────┴──────────┴──────────┴───┴───────┴────────────┴───────────────┴───────────────┘

# %%
joined_df = residuals_df.join(events_df, on= 'composite_event_id', how = 'left')

# %%
joined_df
# Out:
# shape: (431_947, 28)
# ┌────────┬────────────┬───────────┬────────────┬───┬────────────┬───────┬────────────┬────────────┐
# │        ┆ Predicted  ┆ Theoretic ┆ Residuals  ┆ … ┆ total_hits ┆ class ┆ mass       ┆ ring_radiu │
# │ ---    ┆ ---        ┆ al        ┆ ---        ┆   ┆ ---        ┆ ---   ┆ ---        ┆ s_cal      │
# │ i64    ┆ f64        ┆ ---       ┆ f64        ┆   ┆ u16        ┆ str   ┆ f32        ┆ ---        │
# │        ┆            ┆ f64       ┆            ┆   ┆            ┆       ┆            ┆ f32        │
# ╞════════╪════════════╪═══════════╪════════════╪═══╪════════════╪═══════╪════════════╪════════════╡
# │ 0      ┆ 185.233139 ┆ 184.62913 ┆ -0.604004  ┆ … ┆ 31         ┆ muon  ┆ 105.660004 ┆ 184.629135 │
# │        ┆            ┆ 5         ┆            ┆   ┆            ┆       ┆            ┆            │
# │ 1      ┆ 186.549438 ┆ 188.78466 ┆ 2.235229   ┆ … ┆ 23         ┆ muon  ┆ 105.660004 ┆ 188.784668 │
# │        ┆            ┆ 8         ┆            ┆   ┆            ┆       ┆            ┆            │
# │ 2      ┆ 184.755554 ┆ 183.08953 ┆ -1.666016  ┆ … ┆ 53         ┆ muon  ┆ 105.660004 ┆ 183.089539 │
# │        ┆            ┆ 9         ┆            ┆   ┆            ┆       ┆            ┆            │
# │ 3      ┆ 180.99826  ┆ 182.07502 ┆ 1.076767   ┆ … ┆ 17         ┆ muon  ┆ 105.660004 ┆ 182.075027 │
# │        ┆            ┆ 7         ┆            ┆   ┆            ┆       ┆            ┆            │
# │ …      ┆ …          ┆ …         ┆ …          ┆ … ┆ …          ┆ …     ┆ …          ┆ …          │
# │ 431943 ┆ 177.142563 ┆ 184.64939 ┆ 7.506836   ┆ … ┆ 25         ┆ muon  ┆ 105.660004 ┆ 184.649399 │
# │        ┆            ┆ 9         ┆            ┆   ┆            ┆       ┆            ┆            │
# │ 431944 ┆ 175.116272 ┆ 176.30372 ┆ 1.187454   ┆ … ┆ 17         ┆ muon  ┆ 105.660004 ┆ 176.303726 │
# │        ┆            ┆ 6         ┆            ┆   ┆            ┆       ┆            ┆            │
# │ 431945 ┆ 184.94696  ┆ 183.39344 ┆ -1.553513  ┆ … ┆ 19         ┆ muon  ┆ 105.660004 ┆ 183.393448 │
# │        ┆            ┆ 8         ┆            ┆   ┆            ┆       ┆            ┆            │
# │ 431946 ┆ 183.777588 ┆ 164.38037 ┆ -19.397217 ┆ … ┆ 37         ┆ muon  ┆ 105.660004 ┆ 164.380371 │
# │        ┆            ┆ 1         ┆            ┆   ┆            ┆       ┆            ┆            │
# └────────┴────────────┴───────────┴────────────┴───┴────────────┴───────┴────────────┴────────────┘

# %%
test = joined_df.select('track_momentum')

# %%
test = test.to_series()

# %%
test
# Out:
# shape: (431_947,)
# Series: 'track_momentum' [f32]
# [
# 	38.197041
# 	69.928093
# 	34.082951
# 	32.014858
# 	23.331972
# 	14.303932
# 	51.327255
# 	25.855909
# 	46.751801
# 	37.66217
# 	68.756493
# 	29.006683
# 	…
# 	26.330299
# 	41.852882
# 	18.960821
# 	19.110474
# 	41.677452
# 	62.145786
# 	33.123463
# 	43.896561
# 	39.892605
# 	38.261822
# 	24.87092
# 	34.787525
# 	18.648237
# ]

# %%
test.max()
# Out:
# 74.0513916015625

# %%
test = test.cut(np.arange(0, 75, 1))

# %%
test = test.with_columns(pl.col('track_momentum').cast(pl.Float32))

# %%
test
# Out:
# shape: (431_947, 3)
# ┌────────────────┬─────────────┬──────────────┐
# │ track_momentum ┆ break_point ┆ category     │
# │ ---            ┆ ---         ┆ ---          │
# │ f32            ┆ f64         ┆ cat          │
# ╞════════════════╪═════════════╪══════════════╡
# │ 9.442538       ┆ 10.0        ┆ (9.0, 10.0]  │
# │ 9.442658       ┆ 10.0        ┆ (9.0, 10.0]  │
# │ 9.457255       ┆ 10.0        ┆ (9.0, 10.0]  │
# │ 9.457991       ┆ 10.0        ┆ (9.0, 10.0]  │
# │ …              ┆ …           ┆ …            │
# │ 73.864777      ┆ 74.0        ┆ (73.0, 74.0] │
# │ 73.921753      ┆ 74.0        ┆ (73.0, 74.0] │
# │ 73.997108      ┆ 74.0        ┆ (73.0, 74.0] │
# │ 74.051392      ┆ inf         ┆ (74.0, inf]  │
# └────────────────┴─────────────┴──────────────┘

# %%
joined_df = joined_df.join(test, on = 'track_momentum')

# %%
sbn.lineplot(data = joined_df, x = 'category', y = 'Residuals')
fig = plt.gcf()
plt.xticks(rotation=90)
fig.set_size_inches(20, 5)

# %% [markdown]
# In this plot, which represents the relationship between the mean residuals and the momentum bins (1 GeV per bin). The plot also contains the 95% confidence interval (the blue shadow) showing that from thhe momentum 25 the residuals start to stabilize around 0, this suggests that the model is deficient in lower momentum ranges which tend to have more variable ring radii; again suggesting that the model is not learning a pattern in the entire data range but settling for the most common values which are stable in later momentum ranges.

# %%
sbn.lineplot(data = joined_df, x = 'category', y = 'Predicted')
sbn.lineplot(data = joined_df, x = 'category', y = 'Theoretical', color = 'black')
fig = plt.gcf()
plt.xticks(rotation=90)
fig.set_size_inches(20, 5)

# %% [markdown]
# Finally here we can see that, when compared to the calculated ring radius (black line) the model predictions seem to plateau soon and maintain a stable value, proving the assumption that no pattern was being captured by the PointNet model.

# %%
sbn.scatterplot(data = joined_df.to_pandas(), x = 'category', y = 'Residuals')
fig = plt.gcf()
plt.xticks(rotation=90)
fig.set_size_inches(20, 5)

# %%
sbn.boxplot(data = joined_df.to_pandas(), x = 'category', y = 'Predicted')
fig = plt.gcf()
plt.xticks(rotation=90)
fig.set_size_inches(20, 5)

# %%
joined_df.select('category').unique().sort(by = 'category').tail(20)
# Out:
# shape: (20, 1)
# ┌──────────────┐
# │ category     │
# │ ---          │
# │ cat          │
# ╞══════════════╡
# │ (55.0, 56.0] │
# │ (56.0, 57.0] │
# │ (57.0, 58.0] │
# │ (58.0, 59.0] │
# │ …            │
# │ (71.0, 72.0] │
# │ (72.0, 73.0] │
# │ (73.0, 74.0] │
# │ (74.0, inf]  │
# └──────────────┘

# %%
later_subset_joined_df = joined_df.filter(pl.col('category').is_in(joined_df.select('category').unique().sort(by = 'category').tail(50).to_series()))

# %%
sbn.lineplot(data = later_subset_joined_df, x = 'category', y = 'Residuals')
fig = plt.gcf()
plt.xticks(rotation=90)
fig.set_size_inches(20, 5)

# %%
sbn.scatterplot(later_subset_joined_df, x = 'Theoretical', y = 'Residuals', s = 1)
plt.axhline(y=0, color='red', linestyle='--')

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(later_subset_joined_df['Theoretical'], later_subset_joined_df['Predicted'])

# %%
mae
# Out:
# 4.633048169941805

# %%
from sklearn.metrics import r2_score

r2 = r2_score(later_subset_joined_df['Theoretical'], later_subset_joined_df['Predicted'])

# %%
r2
# Out:
# -2.884908647419197

# %%
sbn.scatterplot(later_subset_joined_df, x = 'Theoretical', y = 'Predicted', s = 1)
plt.plot([176, 190], [176, 190], color='black', linestyle='-', linewidth=1)

# %%
sbn.scatterplot(data = joined_df, x = 'ring_radius_cal', y = 'Residuals', s = 1)
plt.axhline(y=0, color='red', linestyle='--')

# %% [markdown]
# # Future Suggestions

# %% [markdown]
# Based on the fact that this model is not learning from the training data supplied to it I suggest the following:
#
# 1. Create a new dataset and make sure to capture trhe entire data range
# 2. Test the convolutional network with an input feature number of 2 and avoid performing the gaussian noise procedure to generate a 3rd
# 3. Substitute the 3rd dimension witht he median hit distance (the most important engineered feature from the XGBoost experiment)
# 4. Try the model on lower momentum bins only, to make sure the model is actually learning
