# %% [markdown]
# ## Gradient boosted decision tree regressor analysis
#
# - **Purpose**: The purpose of this notebook is to test the performance of XGBRegressor
# - **Author**: Crystal Geng

# %% [markdown]
# - **Data**:
#     - Uniformly sampled data where the same number of data was sampled in each track momentum bin, with bin size = 1 GeV/C
# - **Model type**: Regressor
# - **Engineered features**
#     - `x_realigned_min`: minimum realigned hit position x in each event
#     - `x_realigned_max`: maximum realigned hit position x in each event
#     - `x_realigned_mean`: mean realigned hit position x in each event
#     - `x_realigned_median`: median realigned hit position x in each event
#     - `y_reaglined_min`: minimum realigned hit position y in each event
#     - `y_realigned_max`: maximum realigned hit position y in each event
#     - `y_realigned_mean`: mean realigned hit position y in each event
#     - `y_realigned_median`: median reaglined hit position y in each event
#     - `min(x+y)`: minimum reaglined hit position x + y in each event
#     - `max(x+y)`: maximum realigned hit position x + y in each event
#     - `min(x-y)`: minimum realigned hit position x - y in each event
#     - `max(x-y)`: maximum realigned hit position x - y in each event
#     - `inner_ring_radius`: radius of the largest circle that ejects all the points to the outside (inner circle)
#     - `outer_ring_radius`: radius of the smallest circle that includes all the points inside (outer circle)
#     - `max_x-min_x`: maximum realigned hit position x minus minimum realigned hit position x in each event
#     - `max_y-min_y`: maximum realigned hit position y minus minimum realigned hit position y in each event
# - **Preprocessing**:
#     - Only the in-time hits where delta <= 0.5 are included
#     - Only muons are included
#     - Events with ring centred position greater than 1000 are excluded
#     - Examples with NAs are dropped
# - **Training**:
#     - XGBRegressor for training with default values

# %%
import numpy as np 
import pandas as pd
import os
import matplotlib.pyplot as plt
import sys
import glob
import warnings
from sklearn.model_selection import train_test_split
import xgboost as xgb
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### 1. Read the data

# %% [markdown]
# #### Read the concatenated hits and events data

# %%
hit_data_uniform = pd.read_csv('../hit_data_uniform.csv')

# %% [markdown]
# #### Read the uniformly sampled events data (for retrieving the radius)

# %%
sampled_data = pd.read_csv('../sampled_data_uniform.csv')

# %%
hit_data_uniform = hit_data_uniform.drop(hit_data_uniform.columns[0], axis=1)

# %%
sampled_data = sampled_data[["event", "ring_radius", "ring_centre_pos_x", "ring_centre_pos_y"]]

# %%
merged_df = sampled_data.merge(hit_data_uniform, left_on='event', right_on='event')

# %%
merged_df
# Out:
#            event  ring_radius  ring_centre_pos_x  ring_centre_pos_y      x  \
# 0          80852    169.37271        -238.677630        -163.017230  -36.0
# 1          80852    169.37271        -238.677630        -163.017230  -45.0
# 2          80852    169.37271        -238.677630        -163.017230  108.0
# 3          80852    169.37271        -238.677630        -163.017230  234.0
# 4          80852    169.37271        -238.677630        -163.017230  207.0
# ...          ...          ...                ...                ...    ...
# 9366531  2178107    183.84737         -11.867355          34.194088  144.0
# 9366532  2178107    183.84737         -11.867355          34.194088  234.0
# 9366533  2178107    183.84737         -11.867355          34.194088   -9.0
# 9366534  2178107    183.84737         -11.867355          34.194088  -63.0
# 9366535  2178107    183.84737         -11.867355          34.194088   36.0
#
#               y  mirror  x_realigned  y_realigned   hit_time  chod_time  \
# 0         77.94     0.0    55.877628   221.157230  53.321484  19.203901
# 1         62.35     0.0    46.877628   205.567226  53.034840  19.203901
# 2        140.30     0.0   199.877628   283.517230  53.126720  19.203901
# 3        109.12     0.0   325.877628   252.337230  52.964043  19.203901
# 4        124.71     0.0   298.877628   267.927226  54.722860  19.203901
# ...         ...     ...          ...          ...        ...        ...
# 9366531  202.65     0.0     9.067355   148.655906  10.620909  10.989535
# 9366532  -77.94     0.0    99.067355  -131.934090  10.970553  10.989535
# 9366533  155.88     0.0  -143.932645   101.885917  10.578908  10.989535
# 9366534  124.71     0.0  -197.932645    70.715911  11.381413  10.989535
# 9366535 -109.12     1.0  -148.832645  -152.814091   1.495441  10.989535
#
#          chod_delta class  momentum
# 0         34.117584  muon  20.45610
# 1         33.830940  muon  20.45610
# 2         33.922820  muon  20.45610
# 3         33.760140  muon  20.45610
# 4         35.518960  muon  20.45610
# ...             ...   ...       ...
# 9366531   -0.368627  pion  44.02878
# 9366532   -0.018982  pion  44.02878
# 9366533   -0.410627  pion  44.02878
# 9366534    0.391878  pion  44.02878
# 9366535   -9.494094  pion  44.02878
#
# [9366536 rows x 14 columns]

# %% [markdown]
# ### 2. Preprocessing

# %% [markdown]
# #### Compute the distance between each hit point and the fitted ring centre

# %%
merged_df["distance"] = (
    (merged_df["ring_centre_pos_x"] - merged_df["x_realigned"]) ** 2 +
    (merged_df["ring_centre_pos_y"] - merged_df["y_realigned"]) ** 2
) ** 0.5

merged_df
# Out:
#            event  ring_radius  ring_centre_pos_x  ring_centre_pos_y      x  \
# 0          80852    169.37271        -238.677630        -163.017230  -36.0
# 1          80852    169.37271        -238.677630        -163.017230  -45.0
# 2          80852    169.37271        -238.677630        -163.017230  108.0
# 3          80852    169.37271        -238.677630        -163.017230  234.0
# 4          80852    169.37271        -238.677630        -163.017230  207.0
# ...          ...          ...                ...                ...    ...
# 9366531  2178107    183.84737         -11.867355          34.194088  144.0
# 9366532  2178107    183.84737         -11.867355          34.194088  234.0
# 9366533  2178107    183.84737         -11.867355          34.194088   -9.0
# 9366534  2178107    183.84737         -11.867355          34.194088  -63.0
# 9366535  2178107    183.84737         -11.867355          34.194088   36.0
#
#               y  mirror  x_realigned  y_realigned   hit_time  chod_time  \
# 0         77.94     0.0    55.877628   221.157230  53.321484  19.203901
# 1         62.35     0.0    46.877628   205.567226  53.034840  19.203901
# 2        140.30     0.0   199.877628   283.517230  53.126720  19.203901
# 3        109.12     0.0   325.877628   252.337230  52.964043  19.203901
# 4        124.71     0.0   298.877628   267.927226  54.722860  19.203901
# ...         ...     ...          ...          ...        ...        ...
# 9366531  202.65     0.0     9.067355   148.655906  10.620909  10.989535
# 9366532  -77.94     0.0    99.067355  -131.934090  10.970553  10.989535
# 9366533  155.88     0.0  -143.932645   101.885917  10.578908  10.989535
# 9366534  124.71     0.0  -197.932645    70.715911  11.381413  10.989535
# 9366535 -109.12     1.0  -148.832645  -152.814091   1.495441  10.989535
#
#          chod_delta class  momentum    distance
# 0         34.117584  muon  20.45610  484.100005
# 1         33.830940  muon  20.45610  466.257768
# 2         33.922820  muon  20.45610  625.878373
# 3         33.760140  muon  20.45610  700.886557
# 4         35.518960  muon  20.45610  688.969360
# ...             ...   ...       ...         ...
# 9366531   -0.368627  pion  44.02878  116.360517
# 9366532   -0.018982  pion  44.02878  199.762563
# 9366533   -0.410627  pion  44.02878  148.402912
# 9366534    0.391878  pion  44.02878  189.615758
# 9366535   -9.494094  pion  44.02878  231.800668
#
# [9366536 rows x 15 columns]

# %% [markdown]
# #### Filter out the out-of-time hits

# %%
hit_data_uniform_df_intime = merged_df[['event', 'ring_radius', 'x_realigned', 'y_realigned', 'chod_delta', 'class', 'distance']]

# %%
hit_data_uniform_df_intime = hit_data_uniform_df_intime.query('abs(chod_delta) <= 0.5')

# %% [markdown]
# #### Filter the hits data to muons only

# %%
hit_data_uniform_df_intime_muons = hit_data_uniform_df_intime.query('`class` == "muon"')

# %% [markdown]
# #### Compute `x+y` and `x-y` columns

# %%
hit_data_uniform_df_intime_muons['x+y'] = hit_data_uniform_df_intime_muons['x_realigned'] + hit_data_uniform_df_intime_muons['y_realigned']
hit_data_uniform_df_intime_muons['x-y'] = hit_data_uniform_df_intime_muons['x_realigned'] - hit_data_uniform_df_intime_muons['y_realigned']
# Out:
# /var/folders/v0/slk4rwcj0cz5hchw7hz83hlw0000gn/T/ipykernel_52362/3093887954.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hit_data_uniform_df_intime_muons['x+y'] = hit_data_uniform_df_intime_muons['x_realigned'] + hit_data_uniform_df_intime_muons['y_realigned']
# /var/folders/v0/slk4rwcj0cz5hchw7hz83hlw0000gn/T/ipykernel_52362/3093887954.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hit_data_uniform_df_intime_muons['x-y'] = hit_data_uniform_df_intime_muons['x_realigned'] - hit_data_uniform_df_intime_muons['y_realigned']

# %% [markdown]
# #### Compute `max_x`, `min_x`, `median_x`, `mean_x`, `max_y`, `min_y`, `median_y`, `mean_y`, `min(x+y)`, `max(x+y)`, `min(x-y)`, `max(x-y)`

# %%
grouped_hit_data = hit_data_uniform_df_intime_muons.groupby('event').aggregate(
    {'x_realigned':['min', 'max', 'mean', 'median'], 
    'y_realigned':['min','max', 'mean', 'median'],
    'x+y': ['min', 'max'],
    'x-y': ['min', 'max'],
    'distance': ['min', 'max']})
grouped_hit_data.columns = ['x_realigned_min', 'x_realigned_max', 'x_realigned_mean', 'x_realigned_median', 'y_realigned_min', 'y_realigned_max', 'y_realigned_mean', 'y_realigned_median', 'min(x+y)', 'max(x+y)', 'min(x-y)', 'max(x-y)', 'inner_ring_radius', 'outer_ring_radius']
grouped_hit_data= grouped_hit_data.reset_index()
grouped_hit_data
# Out:
#           event  x_realigned_min  x_realigned_max  x_realigned_mean  \
# 0            28      -209.671128       132.328872        -82.852946
# 1            31      -165.334827       181.565173          9.248507
# 2            59      -203.601382       174.398618        -55.101382
# 3            61      -181.854565       169.145435        -17.154565
# 4            68      -223.286990       172.713010        -19.943240
# ...         ...              ...              ...               ...
# 107017  2160095      -210.240756       185.759244         48.616387
# 107018  2160116      -217.829153       124.170847        -72.972010
# 107019  2160117      -197.448833       158.451167        -52.048833
# 107020  2160186      -181.840504       169.159496        -20.532812
# 107021  2160213      -187.011920       181.988080          4.508080
#
#         x_realigned_median  y_realigned_min  y_realigned_max  \
# 0               -74.671128      -182.288785        35.951213
# 1                19.565173      -208.168851       129.491150
# 2               -46.101382      -199.463150       190.246849
# 3               -15.354565      -178.290837       180.239162
# 4                 6.213010      -196.079175       178.050822
# ...                    ...              ...              ...
# 107017           86.759244      -207.641846       150.898155
# 107018         -145.829153      -197.921506       160.608493
# 107019         -125.448833      -201.482132        99.987872
# 107020          -60.340504      -205.775258       168.344737
# 107021          -25.011920      -178.545265       179.984734
#
#         y_realigned_mean  y_realigned_median    min(x+y)    max(x+y)  \
# 0             -74.584240          -57.578786 -271.429914   -3.189916
# 1             -90.406626         -130.228848 -297.253675  176.046324
# 2              49.951853           88.921852 -231.594531  239.935475
# 3             -11.496839          -22.405839 -282.205400  253.444594
# 4              20.702385           61.135823 -305.416168  274.583832
# ...                  ...                 ...         ...         ...
# 107017        -75.508036          -82.931847 -324.352603  255.657399
# 107018        -46.495787          -42.041501 -281.400653  239.779340
# 107019        -61.903561          -76.772133 -300.580966  258.439040
# 107020        -10.322569           -3.125260 -277.855768  248.154234
# 107021          0.406335          -38.255264 -287.617183  261.212815
#
#           min(x-y)    max(x-y)  inner_ring_radius  outer_ring_radius
# 0      -230.032345  267.847660          62.018204         225.144402
# 1      -254.645984  257.794022          39.827731         338.355757
# 2      -288.908229  214.271764          15.701972         338.843124
# 3      -257.153725  242.496269          26.912363         330.094827
# 4      -257.977812  254.842188          99.614349         271.584330
# ...            ...         ...                ...                ...
# 107017 -133.898910  290.221089         125.189626         391.951444
# 107018 -259.667657  259.742347         137.607344         224.544513
# 107019 -133.846698  220.033299         174.905138         315.788637
# 107020 -247.005241  247.814758          49.800621         287.626844
# 107021 -252.406657  262.183339           7.849736         387.210618
#
# [107022 rows x 15 columns]

# %% [markdown]
# #### Compute `max_x-min_x` and `max_y-min_y`

# %%
grouped_hit_data['max_x-min_x'] = grouped_hit_data['x_realigned_max']-grouped_hit_data['x_realigned_min']
grouped_hit_data['max_y-min_y'] = grouped_hit_data['y_realigned_max']-grouped_hit_data['y_realigned_min']

# %% [markdown]
# #### Extracting radius from `sampled_data` (sampled Events data)

# %%
merged_df = pd.merge(sampled_data, grouped_hit_data, left_on='event', right_on='event')

# %%
merged_df
# Out:
#           event  ring_radius  ring_centre_pos_x  ring_centre_pos_y  \
# 0         80852    169.37271        -238.677630        -163.017230
# 1        151070    173.66950        -181.111510         162.464000
# 2       1947832    168.91771         -56.966620          73.462840
# 3        780013    169.10721         -80.256260          99.883410
# 4       1258686    169.08809        -158.903850         149.289110
# ...         ...          ...                ...                ...
# 107017   524583    186.89357         -16.883510          60.280310
# 107018   186952    181.78853         -79.519230          82.514370
# 107019   592331    188.78964        -165.157290          28.893960
# 107020  2080943    188.58577           2.156836         -38.680283
# 107021  1836109    187.28171         -30.668388          73.434390
#
#         x_realigned_min  x_realigned_max  x_realigned_mean  \
# 0           -183.022372       167.977628         29.120485
# 1           -213.588489       164.411511        -67.133943
# 2           -179.833379       144.166621        -53.083379
# 3           -165.543736       167.456264         23.456264
# 4           -190.796146       169.203854        -65.439003
# ...                 ...              ...               ...
# 107017      -183.916489        14.083511        -94.666489
# 107018      -198.180766       -63.180766       -131.180766
# 107019      -220.542712       184.457288         13.457288
# 107020      -202.956836       103.043164        -82.456836
# 107021      -206.131612       162.868388        -45.552664
#
#         x_realigned_median  y_realigned_min  y_realigned_max  \
# 0               131.977628      -127.072769       106.747227
# 1              -159.588489      -203.144005        61.865997
# 2              -121.333379      -140.032838       140.567165
# 3               122.456264      -135.273408       114.146594
# 4              -127.796146      -174.379108       106.210892
# ...                    ...              ...              ...
# 107017          -93.916489      -220.380315       169.339687
# 107018         -117.180766      -169.954376       157.405624
# 107019           44.957288      -209.863962       179.846045
# 107020          -85.956836      -214.949719       174.760287
# 107021          -35.131612      -217.944386        78.235614
#
#         y_realigned_mean  y_realigned_median    min(x+y)    max(x+y)  \
# 0             -17.954202          -25.747772 -247.745151  238.724854
# 1             -55.760367          -16.084000 -263.732494  101.567509
# 2               4.164663            8.062164 -288.686216  228.963782
# 3              -8.165716          -10.563405  -98.167146  189.832854
# 4             -32.969107          -26.289104 -302.175254  166.294751
# ...                  ...                 ...         ...         ...
# 107017        -19.024479          -25.520310 -312.526800  102.423197
# 107018        -52.176597         -107.604374 -285.375140   67.224858
# 107019        -23.918961          -46.188961 -290.116674  270.123324
# 107020        -27.019717          -43.474719 -288.376557  262.223449
# 107021       -111.284387         -124.414388 -314.955999   69.634001
#
#           min(x-y)    max(x-y)  inner_ring_radius  outer_ring_radius  \
# 0      -238.189601  268.050397         112.957102         458.430128
# 1      -221.454486  233.845517         102.874674         413.859388
# 2      -259.810547  241.609459          80.478051         263.607744
# 3      -270.690331  266.729671          42.737796         316.418902
# 4      -234.007037  247.642964          53.135884         395.662920
# ...            ...         ...                ...                ...
# 107017 -290.256176  216.463825         110.550521         280.960015
# 107018 -265.586391  106.773610          75.646337         252.996864
# 107019 -272.618753  273.151252          50.553489         359.303636
# 107020 -270.367118  232.812875         145.497266         224.661533
# 107021 -248.367226  266.222778         139.545844         291.541855
#
#         max_x-min_x  max_y-min_y
# 0             351.0   233.819996
# 1             378.0   265.010002
# 2             324.0   280.600002
# 3             333.0   249.420002
# 4             360.0   280.590000
# ...             ...          ...
# 107017        198.0   389.720001
# 107018        135.0   327.360001
# 107019        405.0   389.710007
# 107020        306.0   389.710007
# 107021        369.0   296.180000
#
# [107022 rows x 20 columns]

# %%
merged_df
# Out:
#           event  ring_radius  ring_centre_pos_x  ring_centre_pos_y  \
# 0         80852    169.37271        -238.677630        -163.017230
# 1        151070    173.66950        -181.111510         162.464000
# 2       1947832    168.91771         -56.966620          73.462840
# 3        780013    169.10721         -80.256260          99.883410
# 4       1258686    169.08809        -158.903850         149.289110
# ...         ...          ...                ...                ...
# 107017   524583    186.89357         -16.883510          60.280310
# 107018   186952    181.78853         -79.519230          82.514370
# 107019   592331    188.78964        -165.157290          28.893960
# 107020  2080943    188.58577           2.156836         -38.680283
# 107021  1836109    187.28171         -30.668388          73.434390
#
#         x_realigned_min  x_realigned_max  x_realigned_mean  \
# 0           -183.022372       167.977628         29.120485
# 1           -213.588489       164.411511        -67.133943
# 2           -179.833379       144.166621        -53.083379
# 3           -165.543736       167.456264         23.456264
# 4           -190.796146       169.203854        -65.439003
# ...                 ...              ...               ...
# 107017      -183.916489        14.083511        -94.666489
# 107018      -198.180766       -63.180766       -131.180766
# 107019      -220.542712       184.457288         13.457288
# 107020      -202.956836       103.043164        -82.456836
# 107021      -206.131612       162.868388        -45.552664
#
#         x_realigned_median  y_realigned_min  y_realigned_max  \
# 0               131.977628      -127.072769       106.747227
# 1              -159.588489      -203.144005        61.865997
# 2              -121.333379      -140.032838       140.567165
# 3               122.456264      -135.273408       114.146594
# 4              -127.796146      -174.379108       106.210892
# ...                    ...              ...              ...
# 107017          -93.916489      -220.380315       169.339687
# 107018         -117.180766      -169.954376       157.405624
# 107019           44.957288      -209.863962       179.846045
# 107020          -85.956836      -214.949719       174.760287
# 107021          -35.131612      -217.944386        78.235614
#
#         y_realigned_mean  y_realigned_median    min(x+y)    max(x+y)  \
# 0             -17.954202          -25.747772 -247.745151  238.724854
# 1             -55.760367          -16.084000 -263.732494  101.567509
# 2               4.164663            8.062164 -288.686216  228.963782
# 3              -8.165716          -10.563405  -98.167146  189.832854
# 4             -32.969107          -26.289104 -302.175254  166.294751
# ...                  ...                 ...         ...         ...
# 107017        -19.024479          -25.520310 -312.526800  102.423197
# 107018        -52.176597         -107.604374 -285.375140   67.224858
# 107019        -23.918961          -46.188961 -290.116674  270.123324
# 107020        -27.019717          -43.474719 -288.376557  262.223449
# 107021       -111.284387         -124.414388 -314.955999   69.634001
#
#           min(x-y)    max(x-y)  inner_ring_radius  outer_ring_radius  \
# 0      -238.189601  268.050397         112.957102         458.430128
# 1      -221.454486  233.845517         102.874674         413.859388
# 2      -259.810547  241.609459          80.478051         263.607744
# 3      -270.690331  266.729671          42.737796         316.418902
# 4      -234.007037  247.642964          53.135884         395.662920
# ...            ...         ...                ...                ...
# 107017 -290.256176  216.463825         110.550521         280.960015
# 107018 -265.586391  106.773610          75.646337         252.996864
# 107019 -272.618753  273.151252          50.553489         359.303636
# 107020 -270.367118  232.812875         145.497266         224.661533
# 107021 -248.367226  266.222778         139.545844         291.541855
#
#         max_x-min_x  max_y-min_y
# 0             351.0   233.819996
# 1             378.0   265.010002
# 2             324.0   280.600002
# 3             333.0   249.420002
# 4             360.0   280.590000
# ...             ...          ...
# 107017        198.0   389.720001
# 107018        135.0   327.360001
# 107019        405.0   389.710007
# 107020        306.0   389.710007
# 107021        369.0   296.180000
#
# [107022 rows x 20 columns]

# %%
grouped_hit_data['ring_radius'] = merged_df['ring_radius']

# %% [markdown]
# #### Drop all the NAs

# %%
grouped_hit_data = grouped_hit_data.dropna()

# %% [markdown]
# #### Filter outliers for radius

# %%
grouped_hit_data = grouped_hit_data.query('ring_radius <= 1000')
grouped_hit_data
# Out:
#           event  x_realigned_min  x_realigned_max  x_realigned_mean  \
# 0            28      -209.671128       132.328872        -82.852946
# 1            31      -165.334827       181.565173          9.248507
# 2            59      -203.601382       174.398618        -55.101382
# 3            61      -181.854565       169.145435        -17.154565
# 4            68      -223.286990       172.713010        -19.943240
# ...         ...              ...              ...               ...
# 107017  2160095      -210.240756       185.759244         48.616387
# 107018  2160116      -217.829153       124.170847        -72.972010
# 107019  2160117      -197.448833       158.451167        -52.048833
# 107020  2160186      -181.840504       169.159496        -20.532812
# 107021  2160213      -187.011920       181.988080          4.508080
#
#         x_realigned_median  y_realigned_min  y_realigned_max  \
# 0               -74.671128      -182.288785        35.951213
# 1                19.565173      -208.168851       129.491150
# 2               -46.101382      -199.463150       190.246849
# 3               -15.354565      -178.290837       180.239162
# 4                 6.213010      -196.079175       178.050822
# ...                    ...              ...              ...
# 107017           86.759244      -207.641846       150.898155
# 107018         -145.829153      -197.921506       160.608493
# 107019         -125.448833      -201.482132        99.987872
# 107020          -60.340504      -205.775258       168.344737
# 107021          -25.011920      -178.545265       179.984734
#
#         y_realigned_mean  y_realigned_median    min(x+y)    max(x+y)  \
# 0             -74.584240          -57.578786 -271.429914   -3.189916
# 1             -90.406626         -130.228848 -297.253675  176.046324
# 2              49.951853           88.921852 -231.594531  239.935475
# 3             -11.496839          -22.405839 -282.205400  253.444594
# 4              20.702385           61.135823 -305.416168  274.583832
# ...                  ...                 ...         ...         ...
# 107017        -75.508036          -82.931847 -324.352603  255.657399
# 107018        -46.495787          -42.041501 -281.400653  239.779340
# 107019        -61.903561          -76.772133 -300.580966  258.439040
# 107020        -10.322569           -3.125260 -277.855768  248.154234
# 107021          0.406335          -38.255264 -287.617183  261.212815
#
#           min(x-y)    max(x-y)  inner_ring_radius  outer_ring_radius  \
# 0      -230.032345  267.847660          62.018204         225.144402
# 1      -254.645984  257.794022          39.827731         338.355757
# 2      -288.908229  214.271764          15.701972         338.843124
# 3      -257.153725  242.496269          26.912363         330.094827
# 4      -257.977812  254.842188          99.614349         271.584330
# ...            ...         ...                ...                ...
# 107017 -133.898910  290.221089         125.189626         391.951444
# 107018 -259.667657  259.742347         137.607344         224.544513
# 107019 -133.846698  220.033299         174.905138         315.788637
# 107020 -247.005241  247.814758          49.800621         287.626844
# 107021 -252.406657  262.183339           7.849736         387.210618
#
#         max_x-min_x  max_y-min_y  ring_radius
# 0             342.0   218.239998    169.37271
# 1             346.9   337.660001    173.66950
# 2             378.0   389.709999    168.91771
# 3             351.0   358.529999    169.10721
# 4             396.0   374.129997    169.08809
# ...             ...          ...          ...
# 107017        396.0   358.540001    186.89357
# 107018        342.0   358.529999    181.78853
# 107019        355.9   301.470004    188.78964
# 107020        351.0   374.119995    188.58577
# 107021        369.0   358.529999    187.28171
#
# [106403 rows x 18 columns]

# %% [markdown]
# ### 3. Training

# %% [markdown]
# #### Train test split

# %%
train_df, test_df = train_test_split(grouped_hit_data, random_state=42)

# %%
X_train = train_df.drop(columns=['ring_radius','event'])
y_train = train_df['ring_radius']
X_test = test_df.drop(columns=['ring_radius','event'])
y_test = test_df['ring_radius']

# %% [markdown]
# #### Fitting the `XGBRegressor` model

# %%
xgb_reg = xgb.XGBRegressor()

# %%
xgb_reg.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#              grow_policy='depthwise', importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012, max_bin=256,
#              max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#              max_depth=6, max_leaves=0, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
reg_metrics = ['neg_root_mean_squared_error', 'r2']

# %%
from sklearn.model_selection import cross_val_score, cross_validate

# %% [markdown]
# #### Cross validate

# %%
xgb_cv = cross_validate(xgb_reg, X_train, y_train, cv=5, return_train_score=True, scoring=reg_metrics)

# %%
pd.DataFrame(xgb_cv)
# Out:
#    fit_time  score_time  test_neg_root_mean_squared_error  \
# 0  2.115165    0.007499                         -6.528172
# 1  2.112879    0.005526                         -6.486445
# 2  2.082465    0.006098                         -6.561469
# 3  2.133665    0.005091                         -7.044046
# 4  2.055981    0.005125                         -6.562134
#
#    train_neg_root_mean_squared_error   test_r2  train_r2
# 0                          -5.523952 -0.048264  0.286256
# 1                          -5.599201 -0.046617  0.268656
# 2                          -5.530895 -0.034622  0.280472
# 3                          -5.498533 -0.035871  0.261560
# 4                          -5.539866 -0.042956  0.279478

# %% [markdown]
# #### Predict and score on the test set

# %%
ypred = xgb_reg.predict(X_test)
mse = mean_squared_error(y_test, ypred)

# %%
pred_df = pd.DataFrame(ypred, y_test).reset_index()
pred_df.columns=['theoretical_radius', 'predcited_radius']

# %%
pred_df
# Out:
#        theoretical_radius  predcited_radius
# 0               186.94850        182.040985
# 1               186.24666        181.639954
# 2               181.21791        182.020264
# 3               189.69760        181.293900
# 4               184.09232        181.371185
# ...                   ...               ...
# 26596           185.21375        182.367035
# 26597           185.27415        181.875717
# 26598           173.03697        181.225769
# 26599           170.28674        181.238708
# 26600           184.91328        181.480087
#
# [26601 rows x 2 columns]

# %%
mse
# Out:
# 44.15870856503324

# %%
rmse = (mse)**0.5
rmse
# Out:
# 6.645201920561424
